# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
# %matplotlib inline

# %%
#Import the data into the dataframe.
# filename = '/home/csoerens/Desktop/python/Frascati_Data_Analysis/data/ana_file.csv'
path = '/Users/Oli/work/Frascati/Frascati_2014_readout/data'
f = 'ana_file.csv'
filename = os.path.join(path,f)

df = pd.read_csv(filename)

# %% [markdown]
# ### Example: Indexing in the dataframe

# %%
#The possible entries we can choose from is:
print list(df) #Or remove the leading print to get a long list.
# Out:
# ['id', 'meas. type', 'run', 'date', 'detector', 'type', 'xpos', 'ypos', 'ref.', 'ref. DAQ', 'att. ref.', 'volt. ref.', 'diamond', 'att. diamond', 'shunt', 'volt. dBLM', 'scpr11', 'scpr12', 'scpr21', 'scpr22', 'udc', 'meas. nr.', 'time', 'UTCtime', 'WC', 'WC sig.', 'WC offset', 'WC noise', 'WC smoothed', 'WC max. sig.', 'WC SNR', 'WC FWHM', 'WC int.', 'WC charge sig.', 'WC ppb', 'icBLM', 'icBLM sig.', 'icBLM offset', 'icBLM noise', 'icBLM smoothed', 'icBLM max. sig.', 'icBLM SNR', 'icBLM max sig. att. corr.', 'icBLM FWHM', 'icBLM int.', 'icBLM int. att. corr.', 'icBLM charge sig.', 'icBLM ppb', 'keithley data', 'keithley timestamp', 'dBLM', 'dBLM sig.', 'dBLM offset', 'dBLM noise', 'dBLM smoothed', 'dBLM max. sig.', 'dBLM SNR', 'dBLM max sig. att. corr.', 'dBLM FWHM', 'dBLM int.', 'dBLM int. att. corr.', 'dBLM charge sig.', 'analyzed', 'file']

# %%
#Plotting a specific kind of data:
data = df['dBLM SNR']
plt.hist(data)
plt.title('Histogram of dBLM SNR\'s')

# %% [markdown]
# ### Example: Using boolean expressions for filtering data

# %%
#This also takes the zero-entries into account, and we're not particularly interested in those. 
#Therefore we'd like to be able to sort the data more elegantly:
data    =     df[df['dBLM SNR'] != 0.0]                              ['dBLM SNR']
#Variable=   df [ boolean condition of which lines we want to plot ] [what column we'd like to plot ]
#Note: the whitespace is not important:
data = df[df['dBLM SNR'] != 0.0]['dBLM SNR']
plt.hist(data)
plt.title('Histogram of non-zero dBLM SNR\'s')
plt.xlabel('SNR')
plt.ylabel('Occurences')

# %%
#Boolean selection of data also works with strings:
# If I want the voltage scans, identified by the tag 'meas. type', I can filter with 'vs':
datax = df[df['meas. type']=='vs']['WC offset']
datay = df[df['meas. type']=='vs']['icBLM offset']
plt.plot(datax, datay, 'o')

# %% [markdown]
# ### Example: Elaborate indexing:

# %%
#It's possible to apply more than one filter at a time with & (and) and | (or):
data = df[(df['volt. dBLM']==100.0)  & (df['dBLM SNR'] > 0.0)]['dBLM SNR']
plt.hist(data)
plt.title('Histogram of non-zero dBLM SNR\'s, with 100V dBLM excitation')
plt.xlabel('SNR')
plt.ylabel('Occurences')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-aea3cebbdddb> in <module>()
#       1 #It's possible to apply more than one filter at a time with & (and) and | (or):
#       2 data = df[(df['volt. dBLM']==100.0)  & (df['dBLM SNR'] > 0.0)]['dBLM SNR']
# ----> 3 plt.hist(data)
#       4 plt.title('Histogram of non-zero dBLM SNR\'s, with 100V dBLM excitation')
#       5 plt.xlabel('SNR')
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2339         ax.hold(hold)
#    2340     try:
# -> 2341         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2342         draw_if_interactive()
#    2343     finally:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    7648         # Massage 'x' for processing.
#    7649         # NOTE: Be sure any changes here is also done below to 'weights'
# -> 7650         if isinstance(x, np.ndarray) or not iterable(x[0]):
#    7651             # TODO: support masked arrays;
#    7652             x = np.asarray(x)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     489     def __getitem__(self, key):
#     490         try:
# --> 491             result = self.index.get_value(self, key)
#     492             if isinstance(result, np.ndarray):
#     493                 return self._constructor(result,index=[key]*len(result)).__finalize__(self)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1036
#    1037             try:
# -> 1038                 return tslib.get_value_box(s, key)
#    1039             except IndexError:
#    1040                 raise
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tslib.so in pandas.tslib.get_value_box (pandas/tslib.c:9561)()
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/tslib.so in pandas.tslib.get_value_box (pandas/tslib.c:9408)()
#
# IndexError: index out of bounds
